# %% [markdown]
# # Titanic
#
# Let's go)
#
# ------------
#
#
# **Часть 1: Анализ данных:**
#
# 1) Анализ особенностей.
#
# 2) Поиск любых отношений или трендов с учетом множества фич.
#
# **Часть 2: Разработка функций и очистка данных:**
#
# 1) Добавление нескольких фич.
#
# 2) Удаление избыточных фич.
#
# 3) Преобразование фич в подходящую вид для моделирования.
#
# **Часть 3: Прогностическое моделирование**
#
# 1) Выполнение основных алгоритмов.
#
# 2) Кросс-валидация.
#
# 3) Ensembling.
#
# 4) Важные особенности Экстракция.

# %% [markdown]
# ## Часть 1: Анализ данных:

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('data/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# Посмотрим сколько у нас пропусков в данных.

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Возраст (Age), каюта (Cabin) и порт высадки (Embarked) имеют NaN значения. Попробуем это пофиксить.
#
# **Статистика выживших:**

# %%
f,ax=plt.subplots(2,1,figsize=(8,18))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# Из 891 пассажира в тренировочной выборке выживших всего ~350 человек.Тоесть 38,4% от всей тренеровочной выборки пережили катастрофу. Нужно пойти глубже, чтобы лучше понять данные и посмотреть, какие категории пассажиров выжили, а какие нет.
#
# Мы постараемся проверить уровень выживаемости, используя различные особенности набора данных. Некоторые из особенностей - Пол (Sex), Порт Высадки (Embarked), Возраст (Age) и т.д.

# %% [markdown]
# ## Анализ фич
#
# ### Пол (Sex)

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Survived vs Dead')
plt.show()

# %% [markdown]
# Похоже мы нашли нечто интересное. Во первых, количество мужчин на корабле сильно больше чем женьщин. Еще, количество спасенных женьщин в два раза больше чем мужчин. В среднем женьщина спасется с вероятностью в 75%, а мужчина с вероятностью 19%. Боль.
#
# Эта фича выглядит давольно важной, посмотрим остальные.

# %% [markdown]
# ### Класс состоятельности
#
# 1st = Высший класс
#
# 2nd = Средний класс
#
# 3rd = Низший класс

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_10289a2e_f321_11e8_846d_107b4416b9f5row0_col0 {
#             background-color:  #ffff66;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row0_col1 {
#             background-color:  #cee666;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row1_col1 {
#             background-color:  #ffff66;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row1_col2 {
#             background-color:  #ffff66;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row2_col0 {
#             background-color:  #60b066;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row2_col1 {
#             background-color:  #dfef66;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row2_col2 {
#             background-color:  #90c866;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row3_col0 {
#             background-color:  #008066;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row3_col1 {
#             background-color:  #008066;
#         }    #T_10289a2e_f321_11e8_846d_107b4416b9f5row3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_10289a2e_f321_11e8_846d_107b4416b9f5" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_10289a2e_f321_11e8_846d_107b4416b9f5level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row0_col0" class="data row0 col0" >80</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row0_col1" class="data row0 col1" >136</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_10289a2e_f321_11e8_846d_107b4416b9f5level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row1_col0" class="data row1 col0" >97</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row1_col1" class="data row1 col1" >87</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_10289a2e_f321_11e8_846d_107b4416b9f5level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row2_col0" class="data row2 col0" >372</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row2_col1" class="data row2 col1" >119</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_10289a2e_f321_11e8_846d_107b4416b9f5level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row3_col0" class="data row3 col0" >549</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row3_col1" class="data row3 col1" >342</td>
#         <td id="T_10289a2e_f321_11e8_846d_107b4416b9f5row3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# На данных графиках отчетлво видно что пассажиры первого класса получают высокий приоритет на спасение. Несмотря на то, что количество пассажиров третьего класса на много больше чем первого, выживаемостьу них составляет около 25%.
# Для пассажиров первого класса выживаемость составляет около 64%, второй класс - 48%. Как мы видим, деньги играют важную роль. Hello cruel world.
#
# Проверим выживаемость по полу и классу.

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6247a590_f333_11e8_846d_107b4416b9f5row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row0_col1 {
#             background-color:  #ffff66;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row0_col2 {
#             background-color:  #f1f866;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row0_col3 {
#             background-color:  #ffff66;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row1_col0 {
#             background-color:  #96cb66;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row1_col1 {
#             background-color:  #a3d166;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row1_col2 {
#             background-color:  #f1f866;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row1_col3 {
#             background-color:  #cfe766;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row2_col0 {
#             background-color:  #a7d366;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row2_col1 {
#             background-color:  #85c266;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row2_col2 {
#             background-color:  #6eb666;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row2_col3 {
#             background-color:  #85c266;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row3_col0 {
#             background-color:  #cde666;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row3_col1 {
#             background-color:  #f0f866;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row3_col2 {
#             background-color:  #ffff66;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row3_col3 {
#             background-color:  #f7fb66;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row4_col0 {
#             background-color:  #008066;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row4_col1 {
#             background-color:  #008066;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row4_col2 {
#             background-color:  #008066;
#         }    #T_6247a590_f333_11e8_846d_107b4416b9f5row4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6247a590_f333_11e8_846d_107b4416b9f5" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row0_col0" class="data row0 col0" >3</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row0_col1" class="data row0 col1" >6</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row0_col2" class="data row0 col2" >72</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row1_col0" class="data row1 col0" >91</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row1_col1" class="data row1 col1" >70</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row1_col2" class="data row1 col2" >72</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row2_col0" class="data row2 col0" >77</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row2_col1" class="data row2 col1" >91</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row2_col2" class="data row2 col2" >300</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row3_col0" class="data row3 col0" >45</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row3_col1" class="data row3 col1" >17</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row3_col2" class="data row3 col2" >47</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_6247a590_f333_11e8_846d_107b4416b9f5level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row4_col0" class="data row4 col0" >216</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row4_col1" class="data row4 col1" >184</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row4_col2" class="data row4 col2" >491</td>
#         <td id="T_6247a590_f333_11e8_846d_107b4416b9f5row4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# Заюзаем **FactorPlot** , будет луше видно разделение на категории.
#
# Подведя итог по этим двум графикам, можно сказать, женьщины первого класса выживают с 95% вероятностью, так как умерли 3 из 94 женьщин первого класса.
#
# В принципе женьщинам был предоставлен приоритет во время спасения, даже по сравнению с мужчинами первого класса.
#
# Попробуем дальше посмотреть класс пассажиров.
#
# ### Возраст (Age)

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
